# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("full_report.csv")
print(df.shape)
# Out:
# (67, 17)

# %%
df.columns
# Out:
# Index(['number', 'date_time', 'new_cases', 'new_deaths', 'recovered', 'active',
#        'deaths', 'suspicious', 'accumulated', 'discarted', 'beni',
#        'chuquisaca', 'cochabamba', 'la_paz', 'pando', 'santa_cruz', 'tarija'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   number       67 non-null     object
#  1   date_time    67 non-null     object
#  2   new_cases    66 non-null     float64
#  3   new_deaths   67 non-null     object
#  4   recovered    67 non-null     float64
#  5   active       67 non-null     float64
#  6   deaths       67 non-null     float64
#  7   suspicious   67 non-null     float64
#  8   accumulated  67 non-null     object
#  9   discarted    67 non-null     float64
#  10  beni         39 non-null     object
#  11  chuquisaca   51 non-null     object
#  12  cochabamba   49 non-null     object
#  13  la_paz       38 non-null     object
#  14  pando        47 non-null     object
#  15  santa_cruz   59 non-null     object
#  16  tarija       24 non-null     object
# dtypes: float64(6), object(11)
# memory usage: 9.0+ KB

# %%
df.sort_values(by="number")
# Out:
#     number                                  date_time  new_cases new_deaths  \
# 33  N° 267      Lunes 07 de diciembre de 2020 (21:30}        NaN     HOY +2
# 29  N° 268     Martes 08 de diciembre de 2020 (21:30)    189.000     HOY +5
# 27  N° 269  Miércoles 09 de diciembre de 2020 (21:30)    214.000     HOY +2
# 46  N° 270     Jueves 10 de diciembre de 2020 (21:30)    325.000     HOY +4
# 24  N° 271    Viernes 11 de diciembre de 2020 (21:30)    312.000     HOY +5
# ..     ...                                        ...        ...        ...
# 56  N° 329     Domingo, 07 de febrero de 2021 (20:45)    839.000    HOY +43
# 45  N° 330       Lunes, 08 de febrero de 2021 (20:30)      1.220    HOY +68
# 54  N° 331      Martes, 09 de febrero de 2027 (20:45)      1.544    HOY +65
# 26  N° 332   Miércoles, 10 de febrero de 2021 (21:00)      1.771    HOY +67
# 28  N° 335      Sdbado, 13 de febrero de 2021 (20:30)    938.000    HOY +48
#
# ...

# %%
df['num'] = df['number'].map(lambda number: number.split(" ")[1])
correct_nums = {"29¢": "299"}
df['num'] = df['num'].replace(correct_nums).astype(int)
# Out:
# 298
# 275
# 274
# 280
# 287
# 321
# 299
# 288
# 320
# 307
# 313
# 295
# 326
# 327
# 311
# 312
# 314
# 292
# 297
# 305
# 300
# 310
# 323
# 319
# 271
# 281
# 332
# 269
# 335
# 268
# 304
# 291
# 324
# 267
# 278
# 325
# 282
# 301
# 286
# 316
# 306
# 276
# 315
# 283
# 294
# 330
# 270
# 289
# 272
# 308
# 317
# 279
# 309
# 322
# 331
# 273
# 329
# 285
# 277
# 284
# 293
# 296
# 303
# 290
# 302
# 318
# 328

# %%
df.sort_values(by='num')
# Out:
#     number                                  date_time  new_cases new_deaths  \
# 33  N° 267      Lunes 07 de diciembre de 2020 (21:30}        NaN     HOY +2
# 29  N° 268     Martes 08 de diciembre de 2020 (21:30)    189.000     HOY +5
# 27  N° 269  Miércoles 09 de diciembre de 2020 (21:30)    214.000     HOY +2
# 46  N° 270     Jueves 10 de diciembre de 2020 (21:30)    325.000     HOY +4
# 24  N° 271    Viernes 11 de diciembre de 2020 (21:30)    312.000     HOY +5
# ..     ...                                        ...        ...        ...
# 56  N° 329     Domingo, 07 de febrero de 2021 (20:45)    839.000    HOY +43
# 45  N° 330       Lunes, 08 de febrero de 2021 (20:30)      1.220    HOY +68
# 54  N° 331      Martes, 09 de febrero de 2027 (20:45)      1.544    HOY +65
# 26  N° 332   Miércoles, 10 de febrero de 2021 (21:00)      1.771    HOY +67
# 28  N° 335      Sdbado, 13 de febrero de 2021 (20:30)    938.000    HOY +48
#
# ...
